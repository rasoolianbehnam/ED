# %%
import numpy as np
import matplotlib.pyplot as plt
import theano as th
import theano.tensor as T
import os
import cv2
import Cython
import numba as nb
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# %load_ext Cython
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib
# The Cython extension is already loaded. To reload it, use:
#   %reload_ext Cython

# %%
pylab.rcParams['figure.figsize'] = (10, 9)
def threshold(img, low, high, label):
    w, h, d = img.shape
    masks = []
    for i in range(3):
        masks.append(img[:, :, i] <= high[i])
        masks.append(img[:, :, i] >= low[i])
    #masks.append(img[:, :, 2] > 200)
    mask = np.ones((w, h))
    for m in masks:
        mask *= m   
    return(mask * label)
def preprocess_label(label):
    m1 = threshold(label, [0, 0, 0], [1, 1, 255], 1)
    m2 = threshold(label, [240, 0, 0], [255, 30, 255], 2)
    m3 = threshold(label, [255, 255, 255], [255, 255, 255], 3)
    m = m1 + m2 + m3
    m = cv2.erode(m, np.ones((3, 3)))
    return m

# %%
def preprocess_image(img, n=5, k=3):
    img_gray = img.mean(axis=2)
    masks = []
    masks.append(img[:, :, 0] >= 240)
    masks.append(img[:, :, 1] <= 200)
    #masks.append(img[:, :, 2] > 200)
    mask = np.ones_like(img_gray)
    for m in masks:
        mask *= m

    kernel = np.ones((5,5),np.uint8)
    dilation = cv2.dilate(mask,kernel,iterations = 1)

    n = 10
    N = n * 2  +1
    k = 3
    kernel = np.ones((N, N), dtype='float32') / (N * N - k*k)
    kernel[n+1-k//2:n+2+k//2, n:n+3] = 0
    kernel = kernel.reshape(1, N*N)
    indices = np.where(dilation)
    new_img = img_gray.copy()
    for k in range(5):
        for i, j in zip(indices[0], indices[1]):
            new_img[i, j] = np.dot(kernel, new_img[i-n:i+n+1, j-n:j+n+1].reshape(N*N, 1))
            #new_img[i, j] = np.median(new_img[i-n:i+n+1, j-n:j+n+1])

    new_img = cv2.GaussianBlur(new_img,(9,9),0)
    #new_img = cv2.medianBlur(new_img, 9)
    return new_img

# %%
# %%cython
# import numpy as np
# import cv2
# from cython cimport boundscheck, wraparound
# from cython.parallel cimport prange
#
# cdef inline modify_image(int[:,:] indices, double[:,:] new_img, double[:,:] kernel, int n):
#     cdef:
#         int i, j, k, N, len_indices, i_indices, t, s
#         double sum_cell
#     N = 2 * n + 1
#     with boundscheck(False), wraparound(False):
#         len_indices = len(indices[0])
#         for i in range(5):
#             for i_indices in range(len_indices):
#                 j = indices[0][i_indices]
#                 k = indices[1][i_indices]
#                 sum_cell= 0
#                 #for t in prange(N, nogil=True):
#                 for t in range(N):
#                     for s in range(N):
#                         sum_cell += kernel[t, s] * new_img[j-n+t, k-n+s]
#                 new_img[j,k] = sum_cell
#
# cpdef preprocess_image(img, int n=5, int k=3):
#     img_gray = img.mean(axis=2)
#     masks = []
#     masks.append(img[:, :, 0] >= 240)
#     masks.append(img[:, :, 1] <= 200)
#     #masks.append(img[:, :, 2] > 200)
#     mask = np.ones_like(img_gray)
#     for m in masks:
#         mask *= m
#
#     kernel = np.ones((5,5),np.uint8)
#     dilation = cv2.dilate(mask,kernel,iterations = 1)
#
#     n = 10
#     N = n * 2  +1
#     k = 3
#     kernel = np.ones((N, N), dtype='float64') / (N * N - k*k)
#     kernel[n+1-k//2:n+2+k//2, n:n+3] = 0
#     indices = np.array(np.where(dilation), dtype='int32')
#     new_img = img_gray.copy()
#     modify_image(indices, new_img, kernel, n)
#     new_img = cv2.GaussianBlur(new_img,(9,9),0)
#     #new_img = cv2.medianBlur(new_img, 9)
#     return new_img

# %%
@nb.jit('(int32[:,:], float64[:,:], float64[:,:], int32)', nopython=True, target='cuda')
def modify_image(indices, new_img, kernel, n):
    N = 2 * n + 1
    len_indices = len(indices[0])
    for i in range(5):
        for i_indices in range(len_indices):
            j = indices[0][i_indices]
            k = indices[1][i_indices]
            sum_cell= 0
            #for t in prange(N, nogil=True):
            for t in range(N):
                for s in range(N):
                    sum_cell += kernel[t, s] * new_img[j-n+t, k-n+s]
            new_img[j,k] = sum_cell

def preprocess_image(img, n=5, k=3):
    img_gray = img.mean(axis=2)
    masks = []
    masks.append(img[:, :, 0] >= 240)
    masks.append(img[:, :, 1] <= 200)
    #masks.append(img[:, :, 2] > 200)
    mask = np.ones_like(img_gray)
    for m in masks:
        mask *= m

    kernel = np.ones((5,5),np.uint8)
    dilation = cv2.dilate(mask,kernel,iterations = 1)

    n = 10
    N = n * 2  +1
    k = 3
    kernel = np.ones((N, N), dtype='float64') / (N * N - k*k)
    kernel[n+1-k//2:n+2+k//2, n:n+3] = 0
    indices = np.array(np.where(dilation), dtype='int32')
    new_img = img_gray.copy()
    modify_image(indices, new_img, kernel, n)
    new_img = cv2.GaussianBlur(new_img,(9,9),0)
    #new_img = cv2.medianBlur(new_img, 9)
    return new_img

# %%
modify_image.inspect_types()
# Out:
# _ZN6cudapy8__main__16modify_image$244E5ArrayIiLi2E1A7mutable7alignedE5ArrayIdLi2E1A7mutable7alignedE5ArrayIdLi2E1A7mutable7alignedEi (array(int32, 2d, A), array(float64, 2d, A), array(float64, 2d, A), int32)
# --------------------------------------------------------------------------------
# # File: <ipython-input-14-1c37751f5ebb>
# # --- LINE 1 ---
# # label 0
#
# @nb.jit('(int32[:,:], float64[:,:], float64[:,:], int32)', nopython=True, target='cuda')
#
# # --- LINE 2 ---
#
# def modify_image(indices, new_img, kernel, n):
#
#     # --- LINE 3 ---
#     #   indices = arg(0, name=indices)  :: array(int32, 2d, A)
#     #   new_img = arg(1, name=new_img)  :: array(float64, 2d, A)
#     #   kernel = arg(2, name=kernel)  :: array(float64, 2d, A)
#     #   n = arg(3, name=n)  :: int32
#     #   $const0.1 = const(int, 2)  :: Literal[int](2)
#     #   $0.3 = $const0.1 * n  :: int64
#     #   del $const0.1
#     #   $const0.4 = const(int, 1)  :: Literal[int](1)
#     #   $0.5 = $0.3 + $const0.4  :: int64
#     #   del $const0.4
#     #   del $0.3
#     #   N = $0.5  :: int64
#     #   del $0.5
#
#     N = 2 * n + 1
#
#     # --- LINE 4 ---
#     #   $0.6 = global(len: <built-in function len>)  :: Function(<built-in function len>)
#     #   $const0.8 = const(int, 0)  :: Literal[int](0)
#     #   $0.9 = static_getitem(value=indices, index=0, index_var=$const0.8)  :: array(int32, 1d, A)
#     #   del $const0.8
#     #   $0.10 = call $0.6($0.9, func=$0.6, args=[Var($0.9, <ipython-input-14-1c37751f5ebb> (4))], kws=(), vararg=None)  :: (array(int32, 1d, A),) -> int64
#     #   del $0.9
#     #   del $0.6
#     #   len_indices = $0.10  :: int64
#     #   del $0.10
#     #   jump 24
#     # label 24
#
#     len_indices = len(indices[0])
#
#     # --- LINE 5 ---
#     #   jump 26
#     # label 26
#     #   $26.1 = global(range: <class 'range'>)  :: Function(<class 'range'>)
#     #   $const26.2 = const(int, 5)  :: Literal[int](5)
#     #   $26.3 = call $26.1($const26.2, func=$26.1, args=[Var($const26.2, <ipython-input-14-1c37751f5ebb> (5))], kws=(), vararg=None)  :: (int64,) -> range_state_int64
#     #   del $const26.2
#     #   del $26.1
#     #   $26.4 = getiter(value=$26.3)  :: range_iter_int64
#     #   del $26.3
#     #   $phi34.1 = $26.4  :: range_iter_int64
#     #   del $26.4
#     #   jump 34
#     # label 34
#     #   $34.2 = iternext(value=$phi34.1)  :: pair<int64, bool>
#     #   $34.3 = pair_first(value=$34.2)  :: int64
#     #   $34.4 = pair_second(value=$34.2)  :: bool
#     #   del $34.2
#     #   $phi36.1 = $34.3  :: int64
#     #   $phi178.1 = $34.3  :: int64
#     #   del $phi178.1
#     #   del $34.3
#     #   $phi178.2 = $phi34.1  :: range_iter_int64
#     #   del $phi178.2
#     #   branch $34.4, 36, 178
#     # label 36
#     #   del $34.4
#     #   i = $phi36.1  :: int64
#     #   del i
#     #   del $phi36.1
#     #   jump 38
#     # label 38
#
#     for i in range(5):
#
#         # --- LINE 6 ---
#         #   jump 40
#         # label 40
#         #   $40.1 = global(range: <class 'range'>)  :: Function(<class 'range'>)
#         #   $40.3 = call $40.1(len_indices, func=$40.1, args=[Var(len_indices, <ipython-input-14-1c37751f5ebb> (4))], kws=(), vararg=None)  :: (int64,) -> range_state_int64
#         #   del $40.1
#         #   $40.4 = getiter(value=$40.3)  :: range_iter_int64
#         #   del $40.3
#         #   $phi48.1 = $40.4  :: range_iter_int64
#         #   del $40.4
#         #   jump 48
#         # label 48
#         #   $48.2 = iternext(value=$phi48.1)  :: pair<int64, bool>
#         #   $48.3 = pair_first(value=$48.2)  :: int64
#         #   $48.4 = pair_second(value=$48.2)  :: bool
#         #   del $48.2
#         #   $phi50.1 = $48.3  :: int64
#         #   $phi174.1 = $48.3  :: int64
#         #   del $phi174.1
#         #   del $48.3
#         #   $phi174.2 = $phi48.1  :: range_iter_int64
#         #   del $phi174.2
#         #   branch $48.4, 50, 174
#         # label 50
#         #   del $48.4
#         #   i_indices = $phi50.1  :: int64
#         #   del $phi50.1
#
#         for i_indices in range(len_indices):
#
#             # --- LINE 7 ---
#             #   $const50.3 = const(int, 0)  :: Literal[int](0)
#             #   $50.4 = static_getitem(value=indices, index=0, index_var=$const50.3)  :: array(int32, 1d, A)
#             #   del $const50.3
#             #   $50.6 = getitem(value=$50.4, index=i_indices)  :: int32
#             #   del $50.4
#             #   j = $50.6  :: int32
#             #   del $50.6
#
#             j = indices[0][i_indices]
#
#             # --- LINE 8 ---
#             #   $const50.8 = const(int, 1)  :: Literal[int](1)
#             #   $50.9 = static_getitem(value=indices, index=1, index_var=$const50.8)  :: array(int32, 1d, A)
#             #   del $const50.8
#             #   $50.11 = getitem(value=$50.9, index=i_indices)  :: int32
#             #   del i_indices
#             #   del $50.9
#             #   k = $50.11  :: int32
#             #   del $50.11
#
#             k = indices[1][i_indices]
#
#             # --- LINE 9 ---
#             #   $const50.12 = const(int, 0)  :: Literal[int](0)
#             #   sum_cell = $const50.12  :: float64
#             #   del $const50.12
#             #   jump 80
#             # label 80
#
#             sum_cell= 0
#
#             # --- LINE 10 ---
#
#             #for t in prange(N, nogil=True):
#
#             # --- LINE 11 ---
#             #   jump 82
#             # label 82
#             #   $82.1 = global(range: <class 'range'>)  :: Function(<class 'range'>)
#             #   $82.3 = call $82.1(N, func=$82.1, args=[Var(N, <ipython-input-14-1c37751f5ebb> (3))], kws=(), vararg=None)  :: (int64,) -> range_state_int64
#             #   del $82.1
#             #   $82.4 = getiter(value=$82.3)  :: range_iter_int64
#             #   del $82.3
#             #   $phi90.1 = $82.4  :: range_iter_int64
#             #   del $82.4
#             #   jump 90
#             # label 90
#             #   $90.2 = iternext(value=$phi90.1)  :: pair<int64, bool>
#             #   $90.3 = pair_first(value=$90.2)  :: int64
#             #   $90.4 = pair_second(value=$90.2)  :: bool
#             #   del $90.2
#             #   $phi92.1 = $90.3  :: int64
#             #   $phi158.1 = $90.3  :: int64
#             #   del $phi158.1
#             #   del $90.3
#             #   $phi158.2 = $phi90.1  :: range_iter_int64
#             #   del $phi158.2
#             #   branch $90.4, 92, 158
#             # label 92
#             #   del $90.4
#             #   t = $phi92.1  :: int64
#             #   del $phi92.1
#             #   jump 94
#             # label 94
#
#             for t in range(N):
#
#                 # --- LINE 12 ---
#                 #   jump 96
#                 # label 96
#                 #   $96.1 = global(range: <class 'range'>)  :: Function(<class 'range'>)
#                 #   $96.3 = call $96.1(N, func=$96.1, args=[Var(N, <ipython-input-14-1c37751f5ebb> (3))], kws=(), vararg=None)  :: (int64,) -> range_state_int64
#                 #   del $96.1
#                 #   $96.4 = getiter(value=$96.3)  :: range_iter_int64
#                 #   del $96.3
#                 #   $phi104.1 = $96.4  :: range_iter_int64
#                 #   del $96.4
#                 #   jump 104
#                 # label 104
#                 #   $104.2 = iternext(value=$phi104.1)  :: pair<int64, bool>
#                 #   $104.3 = pair_first(value=$104.2)  :: int64
#                 #   $104.4 = pair_second(value=$104.2)  :: bool
#                 #   del $104.2
#                 #   $phi106.1 = $104.3  :: int64
#                 #   $phi154.1 = $104.3  :: int64
#                 #   del $phi154.1
#                 #   del $104.3
#                 #   $phi154.2 = $phi104.1  :: range_iter_int64
#                 #   del $phi154.2
#                 #   branch $104.4, 106, 154
#                 # label 106
#                 #   del $104.4
#                 #   s = $phi106.1  :: int64
#                 #   del $phi106.1
#
#                 for s in range(N):
#
#                     # --- LINE 13 ---
#                     #   $106.6 = build_tuple(items=[Var(t, <ipython-input-14-1c37751f5ebb> (11)), Var(s, <ipython-input-14-1c37751f5ebb> (12))])  :: tuple(int64 x 2)
#                     #   $106.7 = getitem(value=kernel, index=$106.6)  :: float64
#                     #   del $106.6
#                     #   $106.11 = j - n  :: int64
#                     #   $106.13 = $106.11 + t  :: int64
#                     #   del $106.11
#                     #   $106.16 = k - n  :: int64
#                     #   $106.18 = $106.16 + s  :: int64
#                     #   del s
#                     #   del $106.16
#                     #   $106.19 = build_tuple(items=[Var($106.13, <ipython-input-14-1c37751f5ebb> (13)), Var($106.18, <ipython-input-14-1c37751f5ebb> (13))])  :: tuple(int64 x 2)
#                     #   del $106.18
#                     #   del $106.13
#                     #   $106.20 = getitem(value=new_img, index=$106.19)  :: float64
#                     #   del $106.19
#                     #   $106.21 = $106.7 * $106.20  :: float64
#                     #   del $106.7
#                     #   del $106.20
#                     #   $106.22 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=sum_cell, rhs=$106.21, static_lhs=Undefined, static_rhs=Undefined)  :: float64
#                     #   del $106.21
#                     #   sum_cell = $106.22  :: float64
#                     #   del $106.22
#                     #   jump 104
#                     # label 154
#                     #   del t
#                     #   del $phi106.1
#                     #   del $phi104.1
#                     #   del $104.4
#                     #   jump 156
#                     # label 156
#                     #   jump 90
#                     # label 158
#                     #   del $phi92.1
#                     #   del $phi90.1
#                     #   del $90.4
#                     #   jump 160
#                     # label 160
#
#                     sum_cell += kernel[t, s] * new_img[j-n+t, k-n+s]
#
#             # --- LINE 14 ---
#             #   $160.5 = build_tuple(items=[Var(j, <ipython-input-14-1c37751f5ebb> (7)), Var(k, <ipython-input-14-1c37751f5ebb> (8))])  :: tuple(int32 x 2)
#             #   del k
#             #   del j
#             #   new_img[$160.5] = sum_cell  :: (array(float64, 2d, A), tuple(int64 x 2), float64) -> none
#             #   del sum_cell
#             #   del $160.5
#             #   jump 48
#             # label 174
#             #   del $phi50.1
#             #   del $phi48.1
#             #   del $48.4
#             #   jump 176
#             # label 176
#             #   jump 34
#             # label 178
#             #   del new_img
#             #   del n
#             #   del len_indices
#             #   del kernel
#             #   del indices
#             #   del N
#             #   del $phi36.1
#             #   del $phi34.1
#             #   del $34.4
#             #   jump 180
#             # label 180
#             #   $const180.1 = const(NoneType, None)  :: none
#             #   $180.2 = cast(value=$const180.1)  :: none
#             #   del $const180.1
#             #   return $180.2
#
#             new_img[j,k] = sum_cell
#
#
# ================================================================================

# %%
@nb.guvectorize(['float64[:], float64[:], float64[:]'], '(n), (n) -> ()', target='cuda')
def euclidean_guvec_cuda(a, b, out):
   N = a.shape[0]
   out[0] = 0.0
   for i in range(N):
       out[0] += a[i]*b[i]
        
@nb.guvectorize(['float64[:], float64[:], float64[:]'], '(n), (n) -> ()', target='cpu')
def euclidean_guvec_cpu(a, b, out):
   N = a.shape[0]
   out[0] = 0.0
   for i in range(N):
       out[0] += a[i]*b[i]       
        
@nb.guvectorize(['float64[:], float64[:], float64[:]'], '(n), (n) -> ()', target='parallel')
def euclidean_guvec_parallel(a, b, out):
   N = a.shape[0]
   out[0] = 0.0
   for i in range(N):
       out[0] += a[i]*b[i]              
        
@nb.vectorize(['float64(float64, float64)'], target='cuda')
def euclidean_vec_cuda(x, y):
    return x * y

@nb.vectorize(['float64(float64, float64)'], target='cpu')
def euclidean_vec_cpu(x, y):
    return x * y

@nb.vectorize(['float64(float64, float64)'], target='parallel')
def euclidean_vec_parallel(x, y):
    return x * y

# %%
N = 1000
a = np.random.rand(N)
b = np.random.rand(N)
#%timeit euclidean_guvec_cuda(a, b)
#%timeit euclidean_guvec_cpu(a, b)
#%timeit euclidean_guvec_parallel(a, b)
#%timeit euclidean_vec_cuda(a, b)
# %timeit euclidean_vec_cpu(a, b)
#%timeit euclidean_vec_parallel(a, b)
# %timeit a * b
# Out:
# 973 ns ± 3.32 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
# 958 ns ± 5.82 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
neighSize = 21
img_shape = (200, 100)
def convert_images(new_img, m, neighSize=neighSize, img_shape=img_shape):
    original = cv2.resize(new_img, img_shape)
    marks = cv2.resize(m, img_shape)
    w, h = original.shape
    numNeighInRows = w - neighSize + 1
    X = []
    y = []
    for i in range(w-neighSize+1):
        X_tmp = []
        y_tmp = []
        for j in range(h-neighSize+1):
            X_tmp.append(original[i:i+neighSize, j:j+neighSize])
            y_tmp.append(marks[i:i+neighSize, j:j+neighSize])
        X.append(X_tmp)
        y.append(y_tmp)

    #assert(X.shape == (w-neighSize+1, h-neighSize+1, neighSize, neighSize))
    #assert(X.shape == y.shape)
    return X, y

# %%
import os
w_cut = 150 
h_cut = 200 
# Set the directory you want to start from
img_dir = '/home/bzr0014/git/sesek2/Behnam Files/original/'
tag_dir = '/home/bzr0014/git/sesek2/Behnam Files/tagged/'
Xs = []
ys = []
imgs = []
labels = []
num_images = 0
for dirName, subdirList, fileList in os.walk(img_dir):
    print('Found directory: %s' % dirName)
    for fname in fileList:
        if fname.endswith('.tif'):
            print('%d\t%s' % (num_images+1, fname))
            main_name = fname.split('.')[0]
            img = plt.imread(img_dir+fname)[w_cut:-w_cut, h_cut:-h_cut]
            imgs.append(img)
            label = plt.imread(tag_dir+main_name+'.jpg')[w_cut:-w_cut, h_cut:-h_cut]
            new_img = preprocess_image(img)
            #imshow(new_img)
            #plt.show()
            m = preprocess_label(label)
            labels.append(m)
            #imshow(m)
            X, y = convert_images(new_img, m)
            Xs.append(X)
            ys.append(y)
            num_images += 1
# Out:
# Found directory: /home/bzr0014/git/sesek2/Behnam Files/original/
# 1	M010-MFC.tif
# 2	M004-MS.tif
# 3	M008-MFC.tif
# 4	M009-MFC.tif
# 5	M003-MFC.tif
# 6	M007-MFC.tif
# 7	M010-MS.tif
# 8	M008-MS.tif
# 9	M002-MS.tif
# 10	M004-MFC.tif
# 11	M005-MFC.tif
# 12	M005-MS.tif
# 13	M006-MS.tif
# 14	M001-MS.tif
# 15	M007-MS.tif
# 16	M009-MS.tif
# 17	M001-MFC.tif
# 18	M002-MFC.tif
# 19	M006-MFC.tif
# 20	M003-MS.tif
# Found directory: /home/bzr0014/git/sesek2/Behnam Files/original/processed

# %%
# %timeit preprocess_image(imgs[0])
# Out:
# 159 ms ± 735 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
imshow(preprocess_image(imgs[0]))

# %%
print('number of images: %d'%num_images)
X_orig = np.array(Xs)
X_orig = (X_orig - X_orig.mean(axis=(1, 2, 3, 4), keepdims=True)) / X_orig.std(axis=(1, 2, 3, 4), keepdims=True)
y_orig = np.array(ys)
print('Shape of original X:', X_orig.shape)
# Out:
# number of images: 20
# Shape of original X: (20, 80, 180, 21, 21)

# %%
def reconstruct(y, neighSize=neighSize):
    a, b, c, d = y.shape
    reconstructed = np.zeros((a+c, b+d))
    for i in range(a):
        for j in range(b):
            reconstructed[i:i+neighSize, j:j+neighSize] = y[i, j]
    return reconstructed
index = np.random.randint(num_images)
print('image number %d'%index)
y_reconstructed = reconstruct(y_orig[index])
X_reconstructed = reconstruct(X_orig[index])
print(y_reconstructed.shape)
print(X_reconstructed.shape)
assert(y_reconstructed.shape == X_reconstructed.shape)
imshow(X_reconstructed)
plt.show()
imshow(y_reconstructed)
# Out:
# image number 6
# (101, 201)
# (101, 201)

# %%
print("size of original X:", X_orig.shape)
N, ww, hh, dd1, dd2 = X_orig.shape
X = X_orig.reshape(N, ww * hh, dd1, dd2, 1)
y = y_orig.reshape(N, ww * hh, dd1, dd2, 1)
train_index = int(num_images * .8)
print(train_index)
X_train = X[:train_index].reshape(-1, dd1, dd2, 1)
y_train = y[:train_index].reshape(-1, dd1, dd2)[:, neighSize//2, neighSize//2]
print('size of trainig image: ', X_train.shape)
X_val = X[train_index:].reshape(-1, dd1, dd2, 1)
y_val = y[train_index:].reshape(-1, dd1, dd2)[:, neighSize//2, neighSize//2]
print('size of test image: ', X_val.shape)
# Out:
# size of original X: (20, 80, 180, 21, 21)
# 16
# size of trainig image:  (230400, 21, 21, 1)
# size of test image:  (57600, 21, 21, 1)

# %%
layer_1_filter_size = 3
layer_1_filter_num = 20
layer_1_stride = 1
layer_2_filter_size = 5
layer_2_filter_num = 20
layer_2_stride = 1
layer_3_filter_num = 20
layer_3_filter_size = 7
layer_3_stride = 1
layer_3_dropout_rate = .25

n_fc1 = 128
fc1_dropout_rate = .5

n_outputs = 4
output_shape = layer_3_filter_num * \
    (neighSize-layer_1_filter_size-layer_2_filter_size-layer_3_filter_size+3)**2

tf.reset_default_graph()

print("output shape:", output_shape)

with tf.name_scope('inputs'):
    X_tf = tf.placeholder(tf.float32, [None, neighSize, neighSize, 1])
    y_tf = tf.placeholder(tf.int64, [None])
    punishment1 = tf.ones_like(y_tf)
    punishment2 = tf.ones_like(y_tf) * 10
    punishment = tf.cast(tf.where(y_tf == 0, punishment1, punishment2), tf.float32)
    training = tf.placeholder_with_default(False, shape=[], name='training')    
    
with tf.name_scope('convs'):
    conv1 = tf.layers.conv2d(X_tf, filters=layer_1_filter_num, kernel_size=layer_1_filter_size,\
                             strides=layer_1_stride, padding='SAME',\
                             activation=tf.nn.relu, name='conv1')
    conv2 = tf.layers.conv2d(X_tf, filters=layer_2_filter_num, kernel_size=layer_2_filter_size,\
                             strides=layer_2_stride, padding='SAME',\
                             activation=tf.nn.relu, name='conv2')
    conv3 = tf.layers.conv2d(X_tf, filters=layer_3_filter_num, kernel_size=layer_3_filter_size,\
                             strides=layer_3_stride, padding='SAME',\
                             activation=tf.nn.relu, name='conv3')   
with tf.name_scope('skip'):
    #skip = conv3 + X_tf
    skip = tf.concat([conv3, X_tf], axis=3)
    print(skip)
    skip_drop = tf.layers.dropout(skip, rate=layer_3_dropout_rate, training=training)
    skip_flat = tf.reshape(skip_drop, shape=[-1, neighSize*neighSize*(layer_3_filter_num+1)])

with tf.name_scope('fc1'):
    fc1 = tf.layers.dense(skip_flat, n_fc1, activation=tf.nn.relu, name='fc1')
    fc1_drop = tf.layers.dropout(fc1, rate=fc1_dropout_rate, training=training)

with tf.name_scope('output'):
    logits = tf.layers.dense(fc1_drop, n_outputs, name='output')
    y_prob = tf.nn.softmax(logits, name='y_prob')

with tf.name_scope('training'):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=y_tf)
    loss = tf.reduce_mean(xentropy)# * punishment)
    optimizer = tf.train.AdamOptimizer()
    training_op = optimizer.minimize(loss)

with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y_tf, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
    
with tf.name_scope('init_and_save'):
    init = tf.global_variables_initializer()
    saver = tf.train.Saver()
# Out:
# output shape: 1620
# Tensor("skip/concat:0", shape=(?, 21, 21, 21), dtype=float32)

# %%
def load_model(checkpoint_path):
    if os.path.isfile(checkpoint_path+'.data-00000-of-00001'):
        print("File already exists")
        saver.restore(sess, checkpoint_path)
    else:
        init.run()
def get_model_params():
    gvars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES)
    return {gvar.op.name: value for gvar, value in zip(gvars, tf.get_default_session().run(gvars))}

def restore_model_params(model_params):
    gvar_names = list(model_params.keys())
    assign_ops = {gvar_name: tf.get_default_graph().get_operation_by_name(gvar_name + "/Assign")
                  for gvar_name in gvar_names}
    init_values = {gvar_name: assign_op.inputs[1] for gvar_name, assign_op in assign_ops.items()}
    feed_dict = {init_values[gvar_name]: model_params[gvar_name] for gvar_name in gvar_names}
    tf.get_default_session().run(assign_ops, feed_dict=feed_dict)

# %%
img_index = 18
with tf.Session() as sess:
    saver.restore(sess, './best')
    output = y_prob.eval(feed_dict={X_tf:X[img_index].reshape(-1, neighSize, neighSize, 1)}).reshape(ww, hh, n_outputs)
    #output = y_prob.eval(feed_dict={X_tf:X_train[train_indicies[:1000]]})
# Out:
# INFO:tensorflow:Restoring parameters from ./best

# %%
pylab.rcParams['figure.figsize'] = (10, 9)
muscle_dict = {}
distances = np.zeros((ww, hh))
kernel = np.ones((3, 3))
threshold = .4
half_length = neighSize // 2
reconstructed_img = cv2.resize(imgs[img_index], img_shape)
imshow(reconstructed_img)
plt.show()
for i in range(0, 4):
    #output_cleaned = cv2.erode(output[:, :, i], kernel)
    #output_cleaned = cv2.dilate(output_cleaned, kernel)
    imshow(output[:, :, i] > threshold)
    plt.show()
    #nonzeros = np.where(output_cleaned > threshold)
    #x_mean = int(np.mean(nonzeros[0]))
    #y_mean = int(np.mean(nonzeros[1]))
    #print(x_mean, y_mean)
    #cv2.circle(distances, (x_mean, y_mean), 5, 255, -1)

# %%
def divide_img(img, axis):
    w, h = img.shape
    output1 = np.zeros_like(img)
    output2 = np.zeros_like(img)
    if axis == 0:
        output1[:w//2, :] = img[:w//2, :]
        output2[w//2:, :] = img[w//2:, :]
    if axis == 1:
        output1[:, :h//2] = img[:, :h//2]
        output2[:, h//2:] = img[:, h//2:]
    return output1, output2
        
def get_midpoints(img):
    points = np.where(img)
    x_mean = np.mean(points[0])
    y_mean = np.mean(points[1])
    return np.array([x_mean, y_mean], dtype='int32')
new_output = output[3:-3, 3:-3, :] 
muscles = []
center_muscle = new_output[:, :, 1] > threshold
muscles.append(center_muscle)

bottom_muscle = new_output[:, :, 2] > threshold
bottom_left, bottom_right,  = divide_img(bottom_muscle, 1)
muscles.append(bottom_left)
muscles.append(bottom_right)
mid_muscle = new_output[:, :, 3] > threshold
mid_left, mid_right = divide_img(mid_muscle, 1)
muscles.append(mid_left)
muscles.append(mid_right)
centers = []
for muscle in muscles:
    centers.append(get_midpoints(muscle))
for center in centers:
    print(center)
# Out:
# [38 87]
# [61 65]
# [ 61 112]
# [39 60]
# [ 39 115]

# %%
pylab.rcParams['figure.figsize'] = (40, 36)
#img = (output[:, :, 0] < .3).astype('uint8')
img = np.zeros_like(new_output[:, :, :3])
img[:, :, 0] = new_output[:, :, 0] < .3
img[:, :, 1] = new_output[:, :, 0] < .3
img[:, :, 2] = new_output[:, :, 0] < .3
for center in centers:
    print(center)
    cv2.circle(img, (center[1], center[0]), 1, 1)
degree = 45
w, h, c = img.shape

a = cos(degree / 180 * np.pi)
b = centers[0][1] - a * centers[0][0]
x0 = 0
y0 = int(b)
x1 = int(w)
y1 = int(a * w + b)
print(x0, y0, x1, y1)
cv2.line(img, (y0, x0), (y1, x1), 1)
for i in range(1, len(centers)):
    center = centers[i]
    b_prime = center[1] + center[0] / a
    x_prime = int(a * (b_prime - b) / (a*a + 1))
    y_prime = int(a * x_prime + b)
    distance = np.sqrt((center[0] - x_prime)**2 + (center[1] - y_prime)**2)
    print("distance: ", distance)
    cv2.line(img, (center[1], center[0]), (y_prime, x_prime), (0, 0, 10))
    cv2.putText(img,"%4.2f"%distance, (center[1]+1, center[0]+1), cv2.FONT_HERSHEY_COMPLEX, .2, (0, 10, 0))
imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [38 87]
# [61 65]
# [ 61 112]
# [39 60]
# [ 39 115]
# 0 60 74 112
# distance:  30.610455730027933
# distance:  7.211102550927978
# distance:  22.02271554554524
# distance:  22.47220505424423

# %%
lbl = cv2.resize(labels[img_index], img_shape)[half_length:-half_length, half_length:-half_length]
print(lbl.shape)
print(output.shape)
for i in range(1, 4):
    zeros = np.zeros_like(output[:, :, 0])
    indices = np.where(lbl == i)
    zeros[indices] = 1
    diff = zeros - (output[:, :, i] > .8)
    print('Muscle number %d'%i)
    print("matching: ", len(indices[0]))
    print("false positive: %4.2f%%"%(100 * len(np.where(diff < 0)[0]) / len(indices[0])))
    print("false negative: %4.2f%%"%(100 * len(np.where(diff > 0)[0]) / len(indices[0])))
    imshow(diff)
    plt.show()
    print('***************************************************')
# Out:
# (80, 180)
# (80, 180, 4)
# Muscle number 1
# matching:  365
# false positive: 2.19%
# false negative: 5.21%
# ***************************************************
# Muscle number 2
# matching:  1230
# false positive: 0.57%
# false negative: 8.54%
# ***************************************************
# Muscle number 3
# matching:  841
# false positive: 2.26%
# false negative: 7.61%
# ***************************************************

# %%
muscle_sizes = []
type_I_errors = []
type_II_errors = []
for img_index in range(16, 20):
    with tf.Session() as sess:
        saver.restore(sess, './best')
        output = y_prob.eval(feed_dict={X_tf:X[img_index].reshape(-1, neighSize, neighSize, 1)}).reshape(ww, hh, n_outputs)
        #output = y_prob.eval(feed_dict={X_tf:X_train[train_indicies[:1000]]})
    lbl = cv2.resize(labels[img_index], img_shape)[half_length:-half_length, half_length:-half_length]
    print(lbl.shape)
    print(output.shape)
    muscle_size = []
    type_I_error = []
    type_II_error = []
    for i in range(1, 4):
        zeros = np.zeros_like(output[:, :, 0])
        indices = np.where(lbl == i)
        zeros[indices] = 1
        diff = zeros - (output[:, :, i] > .8)
        muscle_size.append(len(indices[0]))
        type_I_error.append(len(np.where(diff < 0)[0]))
        type_II_error.append(len(np.where(diff > 0)[0]))
        print('Muscle number %d'%i)
        print("matching: ", len(indices[0]))
        print("false positive: %4.2f%%"%(100 * len(np.where(diff < 0)[0]) / len(indices[0])))
        print("false negative: %4.2f%%"%(100 * len(np.where(diff > 0)[0]) / len(indices[0])))
        print('***************************************************')   
    muscle_sizes.append(muscle_size)
    type_I_errors.append(type_I_error)
    type_II_errors.append(type_II_error)
# Out:
# INFO:tensorflow:Restoring parameters from ./best
# (80, 180)
# (80, 180, 4)
# Muscle number 1
# matching:  451
# false positive: 4.21%
# false negative: 4.21%
# ***************************************************
# Muscle number 2
# matching:  1405
# false positive: 3.20%
# false negative: 12.67%
# ***************************************************
# Muscle number 3
# matching:  709
# false positive: 4.65%
# false negative: 11.28%
# ***************************************************
# INFO:tensorflow:Restoring parameters from ./best
# (80, 180)
# (80, 180, 4)
# Muscle number 1
# matching:  413
# false positive: 2.42%
# false negative: 6.54%
# ***************************************************
# Muscle number 2
# matching:  1557
# false positive: 0.83%
# false negative: 4.50%
# ***************************************************
# Muscle number 3
# matching:  798
# false positive: 3.26%
# false negative: 7.02%
# ***************************************************
# INFO:tensorflow:Restoring parameters from ./best
# (80, 180)
# (80, 180, 4)
# Muscle number 1
# matching:  365
# false positive: 2.19%
# false negative: 5.21%
# ***************************************************
# Muscle number 2
# matching:  1230
# false positive: 0.57%
# false negative: 8.54%
# ***************************************************
# Muscle number 3
# matching:  841
# false positive: 2.26%
# false negative: 7.61%
# ***************************************************
# INFO:tensorflow:Restoring parameters from ./best
# (80, 180)
# (80, 180, 4)
# Muscle number 1
# matching:  404
# false positive: 2.97%
# false negative: 2.48%
# ***************************************************
# Muscle number 2
# matching:  1449
# false positive: 0.48%
# false negative: 6.21%
# ***************************************************
# Muscle number 3
# matching:  728
# false positive: 1.65%
# false negative: 7.69%
# ***************************************************

# %%
muscles = np.array(muscle_sizes)
error_I = np.array(type_I_errors)
error_II = np.array(type_II_errors)

# %%
print(100 * error_I / muscles)
# Out:
# [[4.21286031 3.20284698 4.65444288]
#  [2.42130751 0.83493899 3.25814536]
#  [2.19178082 0.56910569 2.25921522]
#  [2.97029703 0.48309179 1.64835165]]

# %%
print(100 * error_II / muscles)
# Out:
# [[ 4.21286031 12.66903915 11.28349788]
#  [ 6.53753027  4.49582531  7.01754386]
#  [ 5.20547945  8.53658537  7.60998811]
#  [ 2.47524752  6.21118012  7.69230769]]
