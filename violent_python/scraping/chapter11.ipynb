# %%
from selenium import webdriver
import time

# %%
cookies_list = [
    "skin=noskin",
    "session-id=147-8560207-2000217",
    "session-id-time=2082787201l",
    "i18n-prefs=USD",
    "csm-hit=tb:97PF9GZTN081X19BDT1V+s-HZ9EH77SQS7F03MSTA0V|1548961624546&adb:adblk_yes&t:1548961624546",
    "x-wl-uid=1YQVYfILK3q+HxigApP2lwNvfRsFTKcCvysWReFDlsgVMja+rc7H3hlqXtaHNEB0eSdZeIDLCMVk=",
    "ubid-main=132-9538544-5220046",
    "session-token="
]
cookies = {}
for cookie in cookies_list:
    key = cookie.split("=")[0]
    val = cookie[len(key)+1:]
    cookies[key] = val

# %%
driver = webdriver.PhantomJS(executable_path='/home/bzr0014/.local/phantomjs-2.1.1-linux-x86_64/bin/phantomjs')
driver.add_cookie(cookies)
driver.get('https://www.amazon.com')
time.sleep(3)
#print(driver.find_element_by_id('content').text)
driver.save_screenshot('mardas.png')
driver.close()
# Out:
# ---------------------------------------------------------------------------
# InvalidCookieDomainException              Traceback (most recent call last)
# <ipython-input-23-d85e9fc68b6b> in <module>()
#       1 driver = webdriver.PhantomJS(executable_path='/home/bzr0014/.local/phantomjs-2.1.1-linux-x86_64/bin/phantomjs')
# ----> 2 driver.add_cookie(cookies)
#       3 driver.get('https://www.amazon.com')
#       4 time.sleep(3)
#       5 #print(driver.find_element_by_id('content').text)
#
# /home/bzr0014/envs/hack/local/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in add_cookie(self, cookie_dict)
#     892
#     893         """
# --> 894         self.execute(Command.ADD_COOKIE, {'cookie': cookie_dict})
#     895
#     896     # Timeouts
#
# /home/bzr0014/envs/hack/local/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
# ...

# %%
import subprocess

# %%
out = subprocess.check_output(
    """curl 'https://www.amazon.com/?ref_=nav_signin&' -H 'User-Agent: Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:65.0) Gecko/20100101 Firefox/65.0' -H 'Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8' -H 'Accept-Language: en-US,en;q=0.5' --compressed -H 'Referer: https://www.amazon.com/ap/signin?_encoding=UTF8&ignoreAuthState=1&openid.assoc_handle=usflex&openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.mode=checkid_setup&openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0&openid.ns.pape=http%3A%2F%2Fspecs.openid.net%2Fextensions%2Fpape%2F1.0&openid.pape.max_auth_age=0&openid.return_to=https%3A%2F%2Fwww.amazon.com%2F%3Fref_%3Dnav_signin&switch_account=' -H 'Connection: keep-alive' -H 'Cookie: skin=noskin; session-id=147-8560207-2000217; session-id-time=2082787201l; csm-hit=tb:97PF9GZTN081X19BDT1V+s-RE3MKA8MGWRE07Z0XAZA|1548962593713&adb:adblk_yes&t:1548962593981; x-wl-uid=1XzVPVLTeg6iV1BM/5Zg3/ALb/PCftMws7Gx97KmKrImIZFuxK2evyKzKtgNYVaTkVaFtI5E6lQmRHe4l5Ys3hgiQRF0qyNJ3+rzN2mIDXdFowu507euqBWa8H5tk+Rtfl2nYVj58mS8=; ubid-main=132-9538544-5220046; session-token=""; a-ogbcbff=1; x-main="VVPrZpx0yoCA96ZN2QudTrebTg0GmCEONnPXOC6I9xx5sCHI@vysXi6AWM1FEnpl"; at-main=Atza|IwEBIOpxKnU8O0toAX8SvMQQToVd8SbKkbTFDipN7zEaAAHvUIfZKh69JuSEM2xx3jITl1r92ebD298c1yZNAA_oatvfjTJ3jUO7rxMQr6t_S6P4Vu0QcOfEWLNUuA--3NHuXxDvTVZbDVFHlyffpKsxnIMhsMPH9Iw4LGPgHba6QzcyVnNjV5sOnUzQ3wSLFfeWiOTWWg9UrM7dY6LmN9pos_7NUYJ0sux64AgmXNJEI7ojS9j3LB6VOL7mH7ErKWtk0ZpnX9EWyzpCOqTeLauAZ3DwY4M7Dx_qSCYJG1ioQH5pEgUycxEh1YIfXqRdyw3Qb6966ANjg_uG4lMxhSZm7f7-IbEd-PIyvtYPKqotnnSoXmCTyfyy7Pv9UItpdS3cuScv9uuRhbX2-OJ_AgR3BM6W; sess-at-main="Jvf0iGJuE+B1cd2tqEzkKzvMMir3Vw9qQbdkDmHLe5Q="; sst-main=Sst1|PQEAE53nNdYsDx_yulsRiHnLC561rCvwRuKX_enwUVGhTziUsJTuDmSxAXt4L9uZ2tZ_2JQNujSusdL4BR4YOLbLQEFO-rG5qIE51Jock8bgmF4mqOGGWLHsNnLm2IlexbompSkMdtFbBdf3RbGe61P7jheCOzAuaJ7B3TG6yZrTc6eIh5lVEz8Jsk2q60gDNGAKbDwzeOUxlLpPqyW84UrGCieKo1lQbjYl_9o0E2DGwrLtwrT9bHXiecAF3smaW6ppeXIDeJjSeyiCXfgeoQc3koSox1_ptz8P-9UqWOUki-loqZkc_ni5cVdXiNAQnhcJc0hTXBqaHB3DDtLLBh2XJg; lc-main=en_US; i18n-prefs=USD' -H 'Upgrade-Insecure-Requests: 1' -H 'DNT: 1' -H 'Cache-Control: max-age=0' -H 'TE: Trailers'""",
     shell=True
)
print(out)
# Out:
# <!doctype html><html lang="en-us" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8">
# <script type='text/javascript'>var ue_t0=ue_t0||+new Date();</script><!-- sp:feature:cs-optimization -->
# <script type='text/javascript'>
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# (function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){if(1==window.ueinit)try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||"undefined",logLevel:"WARN"})}}}})(ue_csm);
#
#
#     var ue_err_chan = 'jserr-rw';
# ...

# %%
from bs4 import BeautifulSoup
bs = BeautifulSoup(out)
for link in bs.find_all('a'):
    other_link = link.attrs.get('href', None)
    if other_link is not None:
        print other_link
# Out:
# /spark/ref=nav_upnav_merged_T1_Gateway
# /gp/site-directory?ref=navm_em_js_disabled
# /ref=nav_logo
# /ref=nav_logo_prime
# /gp/customer-preferences/select-language/ref=topnav_lang?preferencesReturnUrl=%2F
# https://www.amazon.com/gp/css/homepage.html?ref=nav_youraccount_btn
# /gp/flex/sign-out.html?path=%2Fgp%2Fyourstore%2Fhome&signIn=1&useRedirectOnSuccess=1&action=sign-out&ref=nav_signout
# /gp/css/order-history?ref=nav_orders_first
# /prime?ref=nav_prime_member_btn
# /gp/cart/view.html?ref=nav_cart
# /gp/history?ref=nav_timeline_view_history
# /gp/yourstore/home?ref=nav_cs_ys
# /gp/goldbox?ref=nav_cs_gb_azl
# /gift-cards/b/?ie=UTF8&node=2238192011&ref=nav_cs_gift_cards
# /wholefoods?ref=nav_cs_whole_foods
# /gp/browse.html?node=16115931011&ref=nav_cs_registry
# /b/?_encoding=UTF8&ld=AZUSSOA-sell&node=12766669011&ref=nav_cs_sell
# /gp/help/customer/display.html?nodeId=508510&ref=nav_cs_help
# /gp/help/customer/accessibility
# /access
# #
# ...

# %%
# Out:
# [<a id="nav-top"></a>,
#  <a class="nav-a" href="/spark/ref=nav_upnav_merged_T1_Gateway"><span class="nav-spanAltText">From The Community</span></a>,
#  <a aria-label="Open Menu" href="/gp/site-directory?ref=navm_em_js_disabled" id="nav-hamburger-menu" role="button"><i class="hm-icon nav-sprite"></i></a>,
#  <a aria-label="Amazon" class="nav-logo-link" href="/ref=nav_logo" tabindex="6">\n<span class="nav-sprite nav-logo-base"></span>\n<span class="nav-sprite nav-logo-ext"></span>\n<span class="nav-sprite nav-logo-locale"></span>\n</a>,
#  <a aria-label="" class="nav-sprite nav-logo-tagline nav-prime-try" href="/prime?ref=nav_logo_prime_join" tabindex="7">\n    Try Prime\n  </a>,
# ...
